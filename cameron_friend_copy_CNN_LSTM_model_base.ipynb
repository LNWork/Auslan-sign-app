# %% [markdown]
# <a href="https://colab.research.google.com/github/LNWork/Auslan-sign-app/blob/model/cameron_friend_copy_CNN_LSTM_model_base.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import *
from tensorflow.keras.saving import *
from matplotlib import pyplot as plt
import torch
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import glob
import json
import time

# %%
import re
# test test test

def check_list_contained(A, B):
  # convert list A to string
    A_str = ' '.join(map(str, A))
    # convert list B to string
    B_str = ' '.join(map(str, B))
    # find all instances of A within B
    instances = re.findall(A_str, B_str)

    # return True if any instances were found, False otherwise
    return len(instances) > 0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
SSD_PATH = '/content/gdrive/MyDrive/Auslan App/Data'

# %%
# %cd $SSD_PATH
# %pwd
# Out:
# /content/gdrive/.shortcut-targets-by-id/1tK1wFii8GBHvsqqcHbnxGWpOkelsFvzD/Auslan App/Data
# '/content/gdrive/.shortcut-targets-by-id/1tK1wFii8GBHvsqqcHbnxGWpOkelsFvzD/Auslan App/Data'

# %%
# !unzip json_keypoints.zip -d /images_first_json
# Out:
# Archive:  json_keypoints.zip
#    creating: /images_first_json/json_keypoints/
#   inflating: /images_first_json/json_keypoints/1000_keypoints.json
#   inflating: /images_first_json/json_keypoints/1001_keypoints.json
#   inflating: /images_first_json/json_keypoints/1002_keypoints.json
#   inflating: /images_first_json/json_keypoints/1003_keypoints.json
#   inflating: /images_first_json/json_keypoints/1004_keypoints.json
#   inflating: /images_first_json/json_keypoints/1005_keypoints.json
#   inflating: /images_first_json/json_keypoints/1006_keypoints.json
#   inflating: /images_first_json/json_keypoints/1007_keypoints.json
#   inflating: /images_first_json/json_keypoints/1008_keypoints.json
#   inflating: /images_first_json/json_keypoints/1009_keypoints.json
#   inflating: /images_first_json/json_keypoints/100_keypoints.json
#   inflating: /images_first_json/json_keypoints/1010_keypoints.json
#   inflating: /images_first_json/json_keypoints/1011_keypoints.json
#   inflating: /images_first_json/json_keypoints/1012_keypoints.json
#   inflating: /images_first_json/json_keypoints/1013_keypoints.json
#   inflating: /images_first_json/json_keypoints/1014_keypoints.json
#   inflating: /images_first_json/json_keypoints/1015_keypoints.json
#   inflating: /images_first_json/json_keypoints/1016_keypoints.json
#   inflating: /images_first_json/json_keypoints/1017_keypoints.json
#   inflating: /images_first_json/json_keypoints/1018_keypoints.json
#   inflating: /images_first_json/json_keypoints/1019_keypoints.json
#   inflating: /images_first_json/json_keypoints/101_keypoints.json
#   inflating: /images_first_json/json_keypoints/1020_keypoints.json
#   inflating: /images_first_json/json_keypoints/1021_keypoints.json
#   inflating: /images_first_json/json_keypoints/1022_keypoints.json
#   inflating: /images_first_json/json_keypoints/1023_keypoints.json
#   inflating: /images_first_json/json_keypoints/1024_keypoints.json
#   inflating: /images_first_json/json_keypoints/1025_keypoints.json
#   inflating: /images_first_json/json_keypoints/1026_keypoints.json
#   inflating: /images_first_json/json_keypoints/1027_keypoints.json
#   inflating: /images_first_json/json_keypoints/1028_keypoints.json
#   inflating: /images_first_json/json_keypoints/1029_keypoints.json
#   inflating: /images_first_json/json_keypoints/102_keypoints.json
#   inflating: /images_first_json/json_keypoints/1030_keypoints.json
#   inflating: /images_first_json/json_keypoints/1031_keypoints.json
#   inflating: /images_first_json/json_keypoints/1032_keypoints.json
#   inflating: /images_first_json/json_keypoints/1033_keypoints.json
#   inflating: /images_first_json/json_keypoints/1034_keypoints.json
#   inflating: /images_first_json/json_keypoints/1035_keypoints.json
#   inflating: /images_first_json/json_keypoints/1036_keypoints.json
#   inflating: /images_first_json/json_keypoints/1037_keypoints.json
#   inflating: /images_first_json/json_keypoints/1038_keypoints.json
#   inflating: /images_first_json/json_keypoints/1039_keypoints.json
#   inflating: /images_first_json/json_keypoints/103_keypoints.json
#   inflating: /images_first_json/json_keypoints/1040_keypoints.json
#   inflating: /images_first_json/json_keypoints/1041_keypoints.json
#   inflating: /images_first_json/json_keypoints/1042_keypoints.json
#   inflating: /images_first_json/json_keypoints/1043_keypoints.json
#   inflating: /images_first_json/json_keypoints/1044_keypoints.json
#   inflating: /images_first_json/json_keypoints/1045_keypoints.json
#   inflating: /images_first_json/json_keypoints/1046_keypoints.json
#   inflating: /images_first_json/json_keypoints/1047_keypoints.json
#   inflating: /images_first_json/json_keypoints/1048_keypoints.json
#   inflating: /images_first_json/json_keypoints/1049_keypoints.json
#   inflating: /images_first_json/json_keypoints/104_keypoints.json
#   inflating: /images_first_json/json_keypoints/1050_keypoints.json
#   inflating: /images_first_json/json_keypoints/1051_keypoints.json
#   inflating: /images_first_json/json_keypoints/1052_keypoints.json
#   inflating: /images_first_json/json_keypoints/1053_keypoints.json
#   inflating: /images_first_json/json_keypoints/1054_keypoints.json
#   inflating: /images_first_json/json_keypoints/1055_keypoints.json
#   inflating: /images_first_json/json_keypoints/1056_keypoints.json
#   inflating: /images_first_json/json_keypoints/1057_keypoints.json
#   inflating: /images_first_json/json_keypoints/1058_keypoints.json
#   inflating: /images_first_json/json_keypoints/1059_keypoints.json
#   inflating: /images_first_json/json_keypoints/105_keypoints.json
#   inflating: /images_first_json/json_keypoints/1060_keypoints.json
#   inflating: /images_first_json/json_keypoints/1061_keypoints.json
#   inflating: /images_first_json/json_keypoints/1062_keypoints.json
#   inflating: /images_first_json/json_keypoints/1063_keypoints.json
#   inflating: /images_first_json/json_keypoints/1064_keypoints.json
#   inflating: /images_first_json/json_keypoints/1065_keypoints.json
#   inflating: /images_first_json/json_keypoints/1066_keypoints.json
#   inflating: /images_first_json/json_keypoints/1067_keypoints.json
#   inflating: /images_first_json/json_keypoints/1068_keypoints.json
#   inflating: /images_first_json/json_keypoints/1069_keypoints.json
#   inflating: /images_first_json/json_keypoints/106_keypoints.json
#   inflating: /images_first_json/json_keypoints/1070_keypoints.json
#   inflating: /images_first_json/json_keypoints/1071_keypoints.json
#   inflating: /images_first_json/json_keypoints/1072_keypoints.json
#   inflating: /images_first_json/json_keypoints/1073_keypoints.json
#   inflating: /images_first_json/json_keypoints/1074_keypoints.json
#   inflating: /images_first_json/json_keypoints/1075_keypoints.json
#   inflating: /images_first_json/json_keypoints/1076_keypoints.json
#   inflating: /images_first_json/json_keypoints/1077_keypoints.json
#   inflating: /images_first_json/json_keypoints/1078_keypoints.json
#   inflating: /images_first_json/json_keypoints/1079_keypoints.json
#   inflating: /images_first_json/json_keypoints/107_keypoints.json
#   inflating: /images_first_json/json_keypoints/1080_keypoints.json
#   inflating: /images_first_json/json_keypoints/1081_keypoints.json
#   inflating: /images_first_json/json_keypoints/1082_keypoints.json
#   inflating: /images_first_json/json_keypoints/1083_keypoints.json
#   inflating: /images_first_json/json_keypoints/1084_keypoints.json
#   inflating: /images_first_json/json_keypoints/1085_keypoints.json
#   inflating: /images_first_json/json_keypoints/1086_keypoints.json
#   inflating: /images_first_json/json_keypoints/1087_keypoints.json
#   inflating: /images_first_json/json_keypoints/1088_keypoints.json
#   inflating: /images_first_json/json_keypoints/1089_keypoints.json
#   inflating: /images_first_json/json_keypoints/108_keypoints.json
#   inflating: /images_first_json/json_keypoints/1090_keypoints.json
#   inflating: /images_first_json/json_keypoints/1091_keypoints.json
#   inflating: /images_first_json/json_keypoints/1092_keypoints.json
#   inflating: /images_first_json/json_keypoints/1093_keypoints.json
#   inflating: /images_first_json/json_keypoints/1094_keypoints.json
#   inflating: /images_first_json/json_keypoints/1095_keypoints.json
#   inflating: /images_first_json/json_keypoints/1096_keypoints.json
#   inflating: /images_first_json/json_keypoints/1097_keypoints.json
#   inflating: /images_first_json/json_keypoints/1098_keypoints.json
#   inflating: /images_first_json/json_keypoints/1099_keypoints.json
#   inflating: /images_first_json/json_keypoints/109_keypoints.json
#   inflating: /images_first_json/json_keypoints/10_keypoints.json
#   inflating: /images_first_json/json_keypoints/1100_keypoints.json
#   inflating: /images_first_json/json_keypoints/1101_keypoints.json
#   inflating: /images_first_json/json_keypoints/1102_keypoints.json
#   inflating: /images_first_json/json_keypoints/1103_keypoints.json
#   inflating: /images_first_json/json_keypoints/1104_keypoints.json
#   inflating: /images_first_json/json_keypoints/1105_keypoints.json
#   inflating: /images_first_json/json_keypoints/1106_keypoints.json
#   inflating: /images_first_json/json_keypoints/1107_keypoints.json
#   inflating: /images_first_json/json_keypoints/1108_keypoints.json
#   inflating: /images_first_json/json_keypoints/1109_keypoints.json
#   inflating: /images_first_json/json_keypoints/110_keypoints.json
#   inflating: /images_first_json/json_keypoints/1110_keypoints.json
#   inflating: /images_first_json/json_keypoints/1111_keypoints.json
#   inflating: /images_first_json/json_keypoints/1112_keypoints.json
#   inflating: /images_first_json/json_keypoints/1113_keypoints.json
#   inflating: /images_first_json/json_keypoints/1114_keypoints.json
#   inflating: /images_first_json/json_keypoints/1115_keypoints.json
#   inflating: /images_first_json/json_keypoints/1116_keypoints.json
#   inflating: /images_first_json/json_keypoints/1117_keypoints.json
#   inflating: /images_first_json/json_keypoints/1118_keypoints.json
#   inflating: /images_first_json/json_keypoints/1119_keypoints.json
#   inflating: /images_first_json/json_keypoints/111_keypoints.json
#   inflating: /images_first_json/json_keypoints/1120_keypoints.json
#   inflating: /images_first_json/json_keypoints/1121_keypoints.json
#   inflating: /images_first_json/json_keypoints/1122_keypoints.json
#   inflating: /images_first_json/json_keypoints/1123_keypoints.json
#   inflating: /images_first_json/json_keypoints/1124_keypoints.json
#   inflating: /images_first_json/json_keypoints/1125_keypoints.json
#   inflating: /images_first_json/json_keypoints/1126_keypoints.json
#   inflating: /images_first_json/json_keypoints/1127_keypoints.json
#   inflating: /images_first_json/json_keypoints/1128_keypoints.json
#   inflating: /images_first_json/json_keypoints/1129_keypoints.json
#   inflating: /images_first_json/json_keypoints/112_keypoints.json
#   inflating: /images_first_json/json_keypoints/1130_keypoints.json
#   inflating: /images_first_json/json_keypoints/1131_keypoints.json
#   inflating: /images_first_json/json_keypoints/1132_keypoints.json
#   inflating: /images_first_json/json_keypoints/1133_keypoints.json
#   inflating: /images_first_json/json_keypoints/1134_keypoints.json
#   inflating: /images_first_json/json_keypoints/1135_keypoints.json
#   inflating: /images_first_json/json_keypoints/1136_keypoints.json
#   inflating: /images_first_json/json_keypoints/1137_keypoints.json
#   inflating: /images_first_json/json_keypoints/1138_keypoints.json
#   inflating: /images_first_json/json_keypoints/1139_keypoints.json
#   inflating: /images_first_json/json_keypoints/113_keypoints.json
#   inflating: /images_first_json/json_keypoints/1140_keypoints.json
#   inflating: /images_first_json/json_keypoints/1141_keypoints.json
#   inflating: /images_first_json/json_keypoints/1142_keypoints.json
#   inflating: /images_first_json/json_keypoints/1143_keypoints.json
#   inflating: /images_first_json/json_keypoints/1144_keypoints.json
#   inflating: /images_first_json/json_keypoints/1145_keypoints.json
#   inflating: /images_first_json/json_keypoints/1146_keypoints.json
#   inflating: /images_first_json/json_keypoints/1147_keypoints.json
#   inflating: /images_first_json/json_keypoints/1148_keypoints.json
#   inflating: /images_first_json/json_keypoints/1149_keypoints.json
#   inflating: /images_first_json/json_keypoints/114_keypoints.json
#   inflating: /images_first_json/json_keypoints/1150_keypoints.json
#   inflating: /images_first_json/json_keypoints/1151_keypoints.json
#   inflating: /images_first_json/json_keypoints/1152_keypoints.json
#   inflating: /images_first_json/json_keypoints/1153_keypoints.json
#   inflating: /images_first_json/json_keypoints/1154_keypoints.json
#   inflating: /images_first_json/json_keypoints/1155_keypoints.json
#   inflating: /images_first_json/json_keypoints/1156_keypoints.json
#   inflating: /images_first_json/json_keypoints/1157_keypoints.json
#   inflating: /images_first_json/json_keypoints/1158_keypoints.json
#   inflating: /images_first_json/json_keypoints/1159_keypoints.json
#   inflating: /images_first_json/json_keypoints/115_keypoints.json
#   inflating: /images_first_json/json_keypoints/1160_keypoints.json
#   inflating: /images_first_json/json_keypoints/1161_keypoints.json
#   inflating: /images_first_json/json_keypoints/1162_keypoints.json
#   inflating: /images_first_json/json_keypoints/1163_keypoints.json
#   inflating: /images_first_json/json_keypoints/1164_keypoints.json
#   inflating: /images_first_json/json_keypoints/1165_keypoints.json
#   inflating: /images_first_json/json_keypoints/1166_keypoints.json
#   inflating: /images_first_json/json_keypoints/1167_keypoints.json
#   inflating: /images_first_json/json_keypoints/1168_keypoints.json
#   inflating: /images_first_json/json_keypoints/1169_keypoints.json
#   inflating: /images_first_json/json_keypoints/116_keypoints.json
#   inflating: /images_first_json/json_keypoints/1170_keypoints.json
#   inflating: /images_first_json/json_keypoints/1171_keypoints.json
#   inflating: /images_first_json/json_keypoints/1172_keypoints.json
#   inflating: /images_first_json/json_keypoints/1173_keypoints.json
#   inflating: /images_first_json/json_keypoints/1174_keypoints.json
#   inflating: /images_first_json/json_keypoints/1175_keypoints.json
#   inflating: /images_first_json/json_keypoints/1176_keypoints.json
#   inflating: /images_first_json/json_keypoints/1177_keypoints.json
#   inflating: /images_first_json/json_keypoints/1178_keypoints.json
#   inflating: /images_first_json/json_keypoints/1179_keypoints.json
#   inflating: /images_first_json/json_keypoints/117_keypoints.json
#   inflating: /images_first_json/json_keypoints/1180_keypoints.json
#   inflating: /images_first_json/json_keypoints/1181_keypoints.json
#   inflating: /images_first_json/json_keypoints/1182_keypoints.json
#   inflating: /images_first_json/json_keypoints/1183_keypoints.json
#   inflating: /images_first_json/json_keypoints/1184_keypoints.json
#   inflating: /images_first_json/json_keypoints/1185_keypoints.json
#   inflating: /images_first_json/json_keypoints/1186_keypoints.json
#   inflating: /images_first_json/json_keypoints/1187_keypoints.json
#   inflating: /images_first_json/json_keypoints/1188_keypoints.json
#   inflating: /images_first_json/json_keypoints/1189_keypoints.json
#   inflating: /images_first_json/json_keypoints/118_keypoints.json
#   inflating: /images_first_json/json_keypoints/1190_keypoints.json
#   inflating: /images_first_json/json_keypoints/1191_keypoints.json
#   inflating: /images_first_json/json_keypoints/1192_keypoints.json
#   inflating: /images_first_json/json_keypoints/1193_keypoints.json
#   inflating: /images_first_json/json_keypoints/1194_keypoints.json
#   inflating: /images_first_json/json_keypoints/1195_keypoints.json
#   inflating: /images_first_json/json_keypoints/1196_keypoints.json
#   inflating: /images_first_json/json_keypoints/1197_keypoints.json
#   inflating: /images_first_json/json_keypoints/1198_keypoints.json
#   inflating: /images_first_json/json_keypoints/1199_keypoints.json
#   inflating: /images_first_json/json_keypoints/119_keypoints.json
#   inflating: /images_first_json/json_keypoints/11_keypoints.json
#   inflating: /images_first_json/json_keypoints/1200_keypoints.json
#   inflating: /images_first_json/json_keypoints/1201_keypoints.json
#   inflating: /images_first_json/json_keypoints/1202_keypoints.json
#   inflating: /images_first_json/json_keypoints/1203_keypoints.json
#   inflating: /images_first_json/json_keypoints/1204_keypoints.json
#   inflating: /images_first_json/json_keypoints/1205_keypoints.json
#   inflating: /images_first_json/json_keypoints/1206_keypoints.json
#   inflating: /images_first_json/json_keypoints/1207_keypoints.json
#   inflating: /images_first_json/json_keypoints/1208_keypoints.json
#   inflating: /images_first_json/json_keypoints/1209_keypoints.json
#   inflating: /images_first_json/json_keypoints/120_keypoints.json
#   inflating: /images_first_json/json_keypoints/1210_keypoints.json
#   inflating: /images_first_json/json_keypoints/1211_keypoints.json
#   inflating: /images_first_json/json_keypoints/1212_keypoints.json
#   inflating: /images_first_json/json_keypoints/1213_keypoints.json
#   inflating: /images_first_json/json_keypoints/1214_keypoints.json
#   inflating: /images_first_json/json_keypoints/1215_keypoints.json
#   inflating: /images_first_json/json_keypoints/1216_keypoints.json
#   inflating: /images_first_json/json_keypoints/1217_keypoints.json
#   inflating: /images_first_json/json_keypoints/1218_keypoints.json
#   inflating: /images_first_json/json_keypoints/1219_keypoints.json
#   inflating: /images_first_json/json_keypoints/121_keypoints.json
#   inflating: /images_first_json/json_keypoints/1220_keypoints.json
#   inflating: /images_first_json/json_keypoints/1221_keypoints.json
#   inflating: /images_first_json/json_keypoints/1222_keypoints.json
#   inflating: /images_first_json/json_keypoints/1223_keypoints.json
#   inflating: /images_first_json/json_keypoints/1224_keypoints.json
#   inflating: /images_first_json/json_keypoints/1225_keypoints.json
#   inflating: /images_first_json/json_keypoints/1226_keypoints.json
#   inflating: /images_first_json/json_keypoints/1227_keypoints.json
#   inflating: /images_first_json/json_keypoints/1228_keypoints.json
#   inflating: /images_first_json/json_keypoints/1229_keypoints.json
#   inflating: /images_first_json/json_keypoints/122_keypoints.json
#   inflating: /images_first_json/json_keypoints/1230_keypoints.json
#   inflating: /images_first_json/json_keypoints/1231_keypoints.json
#   inflating: /images_first_json/json_keypoints/1232_keypoints.json
#   inflating: /images_first_json/json_keypoints/1233_keypoints.json
#   inflating: /images_first_json/json_keypoints/1234_keypoints.json
#   inflating: /images_first_json/json_keypoints/1235_keypoints.json
#   inflating: /images_first_json/json_keypoints/1236_keypoints.json
#   inflating: /images_first_json/json_keypoints/1237_keypoints.json
#   inflating: /images_first_json/json_keypoints/1238_keypoints.json
#   inflating: /images_first_json/json_keypoints/1239_keypoints.json
#   inflating: /images_first_json/json_keypoints/123_keypoints.json
#   inflating: /images_first_json/json_keypoints/1240_keypoints.json
#   inflating: /images_first_json/json_keypoints/1241_keypoints.json
#   inflating: /images_first_json/json_keypoints/1242_keypoints.json
#   inflating: /images_first_json/json_keypoints/1243_keypoints.json
#   inflating: /images_first_json/json_keypoints/1244_keypoints.json
#   inflating: /images_first_json/json_keypoints/1245_keypoints.json
#   inflating: /images_first_json/json_keypoints/1246_keypoints.json
#   inflating: /images_first_json/json_keypoints/1247_keypoints.json
#   inflating: /images_first_json/json_keypoints/1248_keypoints.json
#   inflating: /images_first_json/json_keypoints/1249_keypoints.json
#   inflating: /images_first_json/json_keypoints/124_keypoints.json
#   inflating: /images_first_json/json_keypoints/1250_keypoints.json
#   inflating: /images_first_json/json_keypoints/1251_keypoints.json
#   inflating: /images_first_json/json_keypoints/1252_keypoints.json
#   inflating: /images_first_json/json_keypoints/1253_keypoints.json
#   inflating: /images_first_json/json_keypoints/1254_keypoints.json
#   inflating: /images_first_json/json_keypoints/1255_keypoints.json
#   inflating: /images_first_json/json_keypoints/1256_keypoints.json
#   inflating: /images_first_json/json_keypoints/1257_keypoints.json
#   inflating: /images_first_json/json_keypoints/1258_keypoints.json
#   inflating: /images_first_json/json_keypoints/1259_keypoints.json
#   inflating: /images_first_json/json_keypoints/125_keypoints.json
#   inflating: /images_first_json/json_keypoints/1260_keypoints.json
#   inflating: /images_first_json/json_keypoints/1261_keypoints.json
#   inflating: /images_first_json/json_keypoints/1262_keypoints.json
#   inflating: /images_first_json/json_keypoints/1263_keypoints.json
#   inflating: /images_first_json/json_keypoints/1264_keypoints.json
#   inflating: /images_first_json/json_keypoints/1265_keypoints.json
#   inflating: /images_first_json/json_keypoints/1266_keypoints.json
#   inflating: /images_first_json/json_keypoints/1267_keypoints.json
#   inflating: /images_first_json/json_keypoints/1268_keypoints.json
#   inflating: /images_first_json/json_keypoints/1269_keypoints.json
#   inflating: /images_first_json/json_keypoints/126_keypoints.json
#   inflating: /images_first_json/json_keypoints/1270_keypoints.json
#   inflating: /images_first_json/json_keypoints/1271_keypoints.json
#   inflating: /images_first_json/json_keypoints/1272_keypoints.json
#   inflating: /images_first_json/json_keypoints/1273_keypoints.json
#   inflating: /images_first_json/json_keypoints/1274_keypoints.json
#   inflating: /images_first_json/json_keypoints/1275_keypoints.json
#   inflating: /images_first_json/json_keypoints/1276_keypoints.json
#   inflating: /images_first_json/json_keypoints/1277_keypoints.json
#   inflating: /images_first_json/json_keypoints/1278_keypoints.json
#   inflating: /images_first_json/json_keypoints/1279_keypoints.json
#   inflating: /images_first_json/json_keypoints/127_keypoints.json
#   inflating: /images_first_json/json_keypoints/1280_keypoints.json
#   inflating: /images_first_json/json_keypoints/1281_keypoints.json
#   inflating: /images_first_json/json_keypoints/1282_keypoints.json
#   inflating: /images_first_json/json_keypoints/1283_keypoints.json
#   inflating: /images_first_json/json_keypoints/1284_keypoints.json
#   inflating: /images_first_json/json_keypoints/1285_keypoints.json
#   inflating: /images_first_json/json_keypoints/1286_keypoints.json
#   inflating: /images_first_json/json_keypoints/1287_keypoints.json
#   inflating: /images_first_json/json_keypoints/1288_keypoints.json
#   inflating: /images_first_json/json_keypoints/1289_keypoints.json
#   inflating: /images_first_json/json_keypoints/128_keypoints.json
#   inflating: /images_first_json/json_keypoints/1290_keypoints.json
#   inflating: /images_first_json/json_keypoints/1291_keypoints.json
#   inflating: /images_first_json/json_keypoints/1292_keypoints.json
#   inflating: /images_first_json/json_keypoints/1293_keypoints.json
#   inflating: /images_first_json/json_keypoints/1294_keypoints.json
#   inflating: /images_first_json/json_keypoints/1295_keypoints.json
#   inflating: /images_first_json/json_keypoints/1296_keypoints.json
#   inflating: /images_first_json/json_keypoints/1297_keypoints.json
#   inflating: /images_first_json/json_keypoints/1298_keypoints.json
#   inflating: /images_first_json/json_keypoints/1299_keypoints.json
#   inflating: /images_first_json/json_keypoints/129_keypoints.json
#   inflating: /images_first_json/json_keypoints/12_keypoints.json
#   inflating: /images_first_json/json_keypoints/1300_keypoints.json
#   inflating: /images_first_json/json_keypoints/1301_keypoints.json
#   inflating: /images_first_json/json_keypoints/1302_keypoints.json
#   inflating: /images_first_json/json_keypoints/1303_keypoints.json
#   inflating: /images_first_json/json_keypoints/1304_keypoints.json
#   inflating: /images_first_json/json_keypoints/1305_keypoints.json
#   inflating: /images_first_json/json_keypoints/1306_keypoints.json
#   inflating: /images_first_json/json_keypoints/1307_keypoints.json
#   inflating: /images_first_json/json_keypoints/1308_keypoints.json
#   inflating: /images_first_json/json_keypoints/1309_keypoints.json
#   inflating: /images_first_json/json_keypoints/130_keypoints.json
#   inflating: /images_first_json/json_keypoints/1310_keypoints.json
#   inflating: /images_first_json/json_keypoints/1311_keypoints.json
#   inflating: /images_first_json/json_keypoints/1312_keypoints.json
#   inflating: /images_first_json/json_keypoints/1313_keypoints.json
#   inflating: /images_first_json/json_keypoints/1314_keypoints.json
#   inflating: /images_first_json/json_keypoints/1315_keypoints.json
#   inflating: /images_first_json/json_keypoints/1316_keypoints.json
#   inflating: /images_first_json/json_keypoints/1317_keypoints.json
#   inflating: /images_first_json/json_keypoints/1318_keypoints.json
#   inflating: /images_first_json/json_keypoints/1319_keypoints.json
#   inflating: /images_first_json/json_keypoints/131_keypoints.json
#   inflating: /images_first_json/json_keypoints/1320_keypoints.json
#   inflating: /images_first_json/json_keypoints/1321_keypoints.json
#   inflating: /images_first_json/json_keypoints/1322_keypoints.json
#   inflating: /images_first_json/json_keypoints/1323_keypoints.json
#   inflating: /images_first_json/json_keypoints/1324_keypoints.json
#   inflating: /images_first_json/json_keypoints/1325_keypoints.json
#   inflating: /images_first_json/json_keypoints/1326_keypoints.json
#   inflating: /images_first_json/json_keypoints/1327_keypoints.json
#   inflating: /images_first_json/json_keypoints/1328_keypoints.json
#   inflating: /images_first_json/json_keypoints/1329_keypoints.json
#   inflating: /images_first_json/json_keypoints/132_keypoints.json
#   inflating: /images_first_json/json_keypoints/1330_keypoints.json
#   inflating: /images_first_json/json_keypoints/1331_keypoints.json
#   inflating: /images_first_json/json_keypoints/1332_keypoints.json
#   inflating: /images_first_json/json_keypoints/1333_keypoints.json
#   inflating: /images_first_json/json_keypoints/1334_keypoints.json
#   inflating: /images_first_json/json_keypoints/1335_keypoints.json
#   inflating: /images_first_json/json_keypoints/1336_keypoints.json
#   inflating: /images_first_json/json_keypoints/1337_keypoints.json
#   inflating: /images_first_json/json_keypoints/1338_keypoints.json
#   inflating: /images_first_json/json_keypoints/1339_keypoints.json
#   inflating: /images_first_json/json_keypoints/133_keypoints.json
#   inflating: /images_first_json/json_keypoints/1340_keypoints.json
#   inflating: /images_first_json/json_keypoints/1341_keypoints.json
#   inflating: /images_first_json/json_keypoints/1342_keypoints.json
#   inflating: /images_first_json/json_keypoints/1343_keypoints.json
#   inflating: /images_first_json/json_keypoints/1344_keypoints.json
#   inflating: /images_first_json/json_keypoints/1345_keypoints.json
#   inflating: /images_first_json/json_keypoints/1346_keypoints.json
#   inflating: /images_first_json/json_keypoints/1347_keypoints.json
#   inflating: /images_first_json/json_keypoints/1348_keypoints.json
#   inflating: /images_first_json/json_keypoints/1349_keypoints.json
#   inflating: /images_first_json/json_keypoints/134_keypoints.json
#   inflating: /images_first_json/json_keypoints/1350_keypoints.json
#   inflating: /images_first_json/json_keypoints/1351_keypoints.json
#   inflating: /images_first_json/json_keypoints/1352_keypoints.json
#   inflating: /images_first_json/json_keypoints/1353_keypoints.json
#   inflating: /images_first_json/json_keypoints/1354_keypoints.json
#   inflating: /images_first_json/json_keypoints/1355_keypoints.json
#   inflating: /images_first_json/json_keypoints/1356_keypoints.json
#   inflating: /images_first_json/json_keypoints/1357_keypoints.json
#   inflating: /images_first_json/json_keypoints/1358_keypoints.json
#   inflating: /images_first_json/json_keypoints/1359_keypoints.json
#   inflating: /images_first_json/json_keypoints/135_keypoints.json
#   inflating: /images_first_json/json_keypoints/1360_keypoints.json
#   inflating: /images_first_json/json_keypoints/1361_keypoints.json
#   inflating: /images_first_json/json_keypoints/1362_keypoints.json
#   inflating: /images_first_json/json_keypoints/1363_keypoints.json
#   inflating: /images_first_json/json_keypoints/1364_keypoints.json
#   inflating: /images_first_json/json_keypoints/1365_keypoints.json
#   inflating: /images_first_json/json_keypoints/1366_keypoints.json
#   inflating: /images_first_json/json_keypoints/1367_keypoints.json
#   inflating: /images_first_json/json_keypoints/1368_keypoints.json
#   inflating: /images_first_json/json_keypoints/1369_keypoints.json
#   inflating: /images_first_json/json_keypoints/136_keypoints.json
#   inflating: /images_first_json/json_keypoints/1370_keypoints.json
#   inflating: /images_first_json/json_keypoints/1371_keypoints.json
#   inflating: /images_first_json/json_keypoints/1372_keypoints.json
#   inflating: /images_first_json/json_keypoints/1373_keypoints.json
#   inflating: /images_first_json/json_keypoints/1374_keypoints.json
#   inflating: /images_first_json/json_keypoints/1375_keypoints.json
#   inflating: /images_first_json/json_keypoints/1376_keypoints.json
#   inflating: /images_first_json/json_keypoints/1377_keypoints.json
#   inflating: /images_first_json/json_keypoints/1378_keypoints.json
#   inflating: /images_first_json/json_keypoints/1379_keypoints.json
#   inflating: /images_first_json/json_keypoints/137_keypoints.json
#   inflating: /images_first_json/json_keypoints/1380_keypoints.json
#   inflating: /images_first_json/json_keypoints/1381_keypoints.json
#   inflating: /images_first_json/json_keypoints/1382_keypoints.json
#   inflating: /images_first_json/json_keypoints/1383_keypoints.json
#   inflating: /images_first_json/json_keypoints/1384_keypoints.json
#   inflating: /images_first_json/json_keypoints/1385_keypoints.json
#   inflating: /images_first_json/json_keypoints/1386_keypoints.json
#   inflating: /images_first_json/json_keypoints/1387_keypoints.json
#   inflating: /images_first_json/json_keypoints/1388_keypoints.json
#   inflating: /images_first_json/json_keypoints/1389_keypoints.json
#   inflating: /images_first_json/json_keypoints/138_keypoints.json
#   inflating: /images_first_json/json_keypoints/1390_keypoints.json
#   inflating: /images_first_json/json_keypoints/1391_keypoints.json
#   inflating: /images_first_json/json_keypoints/1392_keypoints.json
#   inflating: /images_first_json/json_keypoints/1393_keypoints.json
#   inflating: /images_first_json/json_keypoints/1394_keypoints.json
#   inflating: /images_first_json/json_keypoints/1395_keypoints.json
#   inflating: /images_first_json/json_keypoints/1396_keypoints.json
#   inflating: /images_first_json/json_keypoints/1397_keypoints.json
#   inflating: /images_first_json/json_keypoints/1398_keypoints.json
#   inflating: /images_first_json/json_keypoints/1399_keypoints.json
#   inflating: /images_first_json/json_keypoints/139_keypoints.json
#   inflating: /images_first_json/json_keypoints/13_keypoints.json
#   inflating: /images_first_json/json_keypoints/1400_keypoints.json
#   inflating: /images_first_json/json_keypoints/1401_keypoints.json
#   inflating: /images_first_json/json_keypoints/1402_keypoints.json
#   inflating: /images_first_json/json_keypoints/1403_keypoints.json
#   inflating: /images_first_json/json_keypoints/1404_keypoints.json
#   inflating: /images_first_json/json_keypoints/1405_keypoints.json
#   inflating: /images_first_json/json_keypoints/1406_keypoints.json
#   inflating: /images_first_json/json_keypoints/1407_keypoints.json
#   inflating: /images_first_json/json_keypoints/1408_keypoints.json
#   inflating: /images_first_json/json_keypoints/1409_keypoints.json
#   inflating: /images_first_json/json_keypoints/140_keypoints.json
#   inflating: /images_first_json/json_keypoints/1410_keypoints.json
#   inflating: /images_first_json/json_keypoints/1411_keypoints.json
#   inflating: /images_first_json/json_keypoints/1412_keypoints.json
#   inflating: /images_first_json/json_keypoints/1413_keypoints.json
#   inflating: /images_first_json/json_keypoints/1414_keypoints.json
#   inflating: /images_first_json/json_keypoints/1415_keypoints.json
#   inflating: /images_first_json/json_keypoints/1416_keypoints.json
#   inflating: /images_first_json/json_keypoints/1417_keypoints.json
#   inflating: /images_first_json/json_keypoints/1418_keypoints.json
#   inflating: /images_first_json/json_keypoints/1419_keypoints.json
#   inflating: /images_first_json/json_keypoints/141_keypoints.json
#   inflating: /images_first_json/json_keypoints/1420_keypoints.json
#   inflating: /images_first_json/json_keypoints/1421_keypoints.json
#   inflating: /images_first_json/json_keypoints/1422_keypoints.json
#   inflating: /images_first_json/json_keypoints/1423_keypoints.json
#   inflating: /images_first_json/json_keypoints/1424_keypoints.json
#   inflating: /images_first_json/json_keypoints/1425_keypoints.json
#   inflating: /images_first_json/json_keypoints/1426_keypoints.json
#   inflating: /images_first_json/json_keypoints/1427_keypoints.json
#   inflating: /images_first_json/json_keypoints/1428_keypoints.json
#   inflating: /images_first_json/json_keypoints/1429_keypoints.json
#   inflating: /images_first_json/json_keypoints/142_keypoints.json
#   inflating: /images_first_json/json_keypoints/1430_keypoints.json
#   inflating: /images_first_json/json_keypoints/1431_keypoints.json
#   inflating: /images_first_json/json_keypoints/1432_keypoints.json
#   inflating: /images_first_json/json_keypoints/1433_keypoints.json
#   inflating: /images_first_json/json_keypoints/1434_keypoints.json
#   inflating: /images_first_json/json_keypoints/1435_keypoints.json
#   inflating: /images_first_json/json_keypoints/1436_keypoints.json
#   inflating: /images_first_json/json_keypoints/1437_keypoints.json
#   inflating: /images_first_json/json_keypoints/1438_keypoints.json
#   inflating: /images_first_json/json_keypoints/1439_keypoints.json
#   inflating: /images_first_json/json_keypoints/143_keypoints.json
#   inflating: /images_first_json/json_keypoints/1440_keypoints.json
#   inflating: /images_first_json/json_keypoints/1441_keypoints.json
#   inflating: /images_first_json/json_keypoints/1442_keypoints.json
#   inflating: /images_first_json/json_keypoints/1443_keypoints.json
#   inflating: /images_first_json/json_keypoints/1444_keypoints.json
#   inflating: /images_first_json/json_keypoints/1445_keypoints.json
#   inflating: /images_first_json/json_keypoints/1446_keypoints.json
#   inflating: /images_first_json/json_keypoints/1447_keypoints.json
#   inflating: /images_first_json/json_keypoints/1448_keypoints.json
#   inflating: /images_first_json/json_keypoints/1449_keypoints.json
#   inflating: /images_first_json/json_keypoints/144_keypoints.json
#   inflating: /images_first_json/json_keypoints/1450_keypoints.json
#   inflating: /images_first_json/json_keypoints/1451_keypoints.json
#   inflating: /images_first_json/json_keypoints/1452_keypoints.json
#   inflating: /images_first_json/json_keypoints/1453_keypoints.json
#   inflating: /images_first_json/json_keypoints/1454_keypoints.json
#   inflating: /images_first_json/json_keypoints/1455_keypoints.json
#   inflating: /images_first_json/json_keypoints/1456_keypoints.json
#   inflating: /images_first_json/json_keypoints/1457_keypoints.json
#   inflating: /images_first_json/json_keypoints/1458_keypoints.json
#   inflating: /images_first_json/json_keypoints/1459_keypoints.json
#   inflating: /images_first_json/json_keypoints/145_keypoints.json
#   inflating: /images_first_json/json_keypoints/1460_keypoints.json
#   inflating: /images_first_json/json_keypoints/1461_keypoints.json
#   inflating: /images_first_json/json_keypoints/1462_keypoints.json
#   inflating: /images_first_json/json_keypoints/1463_keypoints.json
#   inflating: /images_first_json/json_keypoints/1464_keypoints.json
#   inflating: /images_first_json/json_keypoints/1465_keypoints.json
#   inflating: /images_first_json/json_keypoints/1466_keypoints.json
#   inflating: /images_first_json/json_keypoints/1467_keypoints.json
#   inflating: /images_first_json/json_keypoints/1468_keypoints.json
#   inflating: /images_first_json/json_keypoints/1469_keypoints.json
#   inflating: /images_first_json/json_keypoints/146_keypoints.json
#   inflating: /images_first_json/json_keypoints/1470_keypoints.json
#   inflating: /images_first_json/json_keypoints/1471_keypoints.json
#   inflating: /images_first_json/json_keypoints/1472_keypoints.json
#   inflating: /images_first_json/json_keypoints/1473_keypoints.json
#   inflating: /images_first_json/json_keypoints/1474_keypoints.json
#   inflating: /images_first_json/json_keypoints/1475_keypoints.json
#   inflating: /images_first_json/json_keypoints/1476_keypoints.json
#   inflating: /images_first_json/json_keypoints/1477_keypoints.json
#   inflating: /images_first_json/json_keypoints/1478_keypoints.json
#   inflating: /images_first_json/json_keypoints/1479_keypoints.json
#   inflating: /images_first_json/json_keypoints/147_keypoints.json
#   inflating: /images_first_json/json_keypoints/1480_keypoints.json
#   inflating: /images_first_json/json_keypoints/1481_keypoints.json
#   inflating: /images_first_json/json_keypoints/1482_keypoints.json
#   inflating: /images_first_json/json_keypoints/1483_keypoints.json
#   inflating: /images_first_json/json_keypoints/1484_keypoints.json
#   inflating: /images_first_json/json_keypoints/1485_keypoints.json
#   inflating: /images_first_json/json_keypoints/1486_keypoints.json
#   inflating: /images_first_json/json_keypoints/1487_keypoints.json
#   inflating: /images_first_json/json_keypoints/1488_keypoints.json
#   inflating: /images_first_json/json_keypoints/1489_keypoints.json
#   inflating: /images_first_json/json_keypoints/148_keypoints.json
#   inflating: /images_first_json/json_keypoints/1490_keypoints.json
#   inflating: /images_first_json/json_keypoints/1491_keypoints.json
#   inflating: /images_first_json/json_keypoints/1492_keypoints.json
#   inflating: /images_first_json/json_keypoints/1493_keypoints.json
#   inflating: /images_first_json/json_keypoints/1494_keypoints.json
#   inflating: /images_first_json/json_keypoints/1495_keypoints.json
#   inflating: /images_first_json/json_keypoints/1496_keypoints.json
#   inflating: /images_first_json/json_keypoints/1497_keypoints.json
#   inflating: /images_first_json/json_keypoints/1498_keypoints.json
#   inflating: /images_first_json/json_keypoints/1499_keypoints.json
#   inflating: /images_first_json/json_keypoints/149_keypoints.json
#   inflating: /images_first_json/json_keypoints/14_keypoints.json
#   inflating: /images_first_json/json_keypoints/1500_keypoints.json
#   inflating: /images_first_json/json_keypoints/1501_keypoints.json
#   inflating: /images_first_json/json_keypoints/1502_keypoints.json
#   inflating: /images_first_json/json_keypoints/1503_keypoints.json
#   inflating: /images_first_json/json_keypoints/1504_keypoints.json
#   inflating: /images_first_json/json_keypoints/1505_keypoints.json
#   inflating: /images_first_json/json_keypoints/1506_keypoints.json
#   inflating: /images_first_json/json_keypoints/1507_keypoints.json
#   inflating: /images_first_json/json_keypoints/1508_keypoints.json
#   inflating: /images_first_json/json_keypoints/1509_keypoints.json
#   inflating: /images_first_json/json_keypoints/150_keypoints.json
#   inflating: /images_first_json/json_keypoints/1510_keypoints.json
#   inflating: /images_first_json/json_keypoints/1511_keypoints.json
#   inflating: /images_first_json/json_keypoints/1512_keypoints.json
#   inflating: /images_first_json/json_keypoints/1513_keypoints.json
#   inflating: /images_first_json/json_keypoints/1514_keypoints.json
#   inflating: /images_first_json/json_keypoints/1515_keypoints.json
#   inflating: /images_first_json/json_keypoints/1516_keypoints.json
#   inflating: /images_first_json/json_keypoints/1517_keypoints.json
#   inflating: /images_first_json/json_keypoints/1518_keypoints.json
#   inflating: /images_first_json/json_keypoints/1519_keypoints.json
#   inflating: /images_first_json/json_keypoints/151_keypoints.json
#   inflating: /images_first_json/json_keypoints/1520_keypoints.json
#   inflating: /images_first_json/json_keypoints/1521_keypoints.json
#   inflating: /images_first_json/json_keypoints/1522_keypoints.json
#   inflating: /images_first_json/json_keypoints/1523_keypoints.json
#   inflating: /images_first_json/json_keypoints/1524_keypoints.json
#   inflating: /images_first_json/json_keypoints/1525_keypoints.json
#   inflating: /images_first_json/json_keypoints/1526_keypoints.json
#   inflating: /images_first_json/json_keypoints/1527_keypoints.json
#   inflating: /images_first_json/json_keypoints/1528_keypoints.json
#   inflating: /images_first_json/json_keypoints/1529_keypoints.json
#   inflating: /images_first_json/json_keypoints/152_keypoints.json
#   inflating: /images_first_json/json_keypoints/1530_keypoints.json
#   inflating: /images_first_json/json_keypoints/1531_keypoints.json
#   inflating: /images_first_json/json_keypoints/1532_keypoints.json
#   inflating: /images_first_json/json_keypoints/1533_keypoints.json
#   inflating: /images_first_json/json_keypoints/1534_keypoints.json
#   inflating: /images_first_json/json_keypoints/1535_keypoints.json
#   inflating: /images_first_json/json_keypoints/1536_keypoints.json
#   inflating: /images_first_json/json_keypoints/1537_keypoints.json
#   inflating: /images_first_json/json_keypoints/1538_keypoints.json
#   inflating: /images_first_json/json_keypoints/1539_keypoints.json
#   inflating: /images_first_json/json_keypoints/153_keypoints.json
#   inflating: /images_first_json/json_keypoints/1540_keypoints.json
#   inflating: /images_first_json/json_keypoints/1541_keypoints.json
#   inflating: /images_first_json/json_keypoints/1542_keypoints.json
#   inflating: /images_first_json/json_keypoints/1543_keypoints.json
#   inflating: /images_first_json/json_keypoints/1544_keypoints.json
#   inflating: /images_first_json/json_keypoints/1545_keypoints.json
#   inflating: /images_first_json/json_keypoints/1546_keypoints.json
#   inflating: /images_first_json/json_keypoints/1547_keypoints.json
#   inflating: /images_first_json/json_keypoints/1548_keypoints.json
#   inflating: /images_first_json/json_keypoints/1549_keypoints.json
#   inflating: /images_first_json/json_keypoints/154_keypoints.json
#   inflating: /images_first_json/json_keypoints/1550_keypoints.json
#   inflating: /images_first_json/json_keypoints/1551_keypoints.json
#   inflating: /images_first_json/json_keypoints/1552_keypoints.json
#   inflating: /images_first_json/json_keypoints/1553_keypoints.json
#   inflating: /images_first_json/json_keypoints/1554_keypoints.json
#   inflating: /images_first_json/json_keypoints/1555_keypoints.json
#   inflating: /images_first_json/json_keypoints/1556_keypoints.json
#   inflating: /images_first_json/json_keypoints/1557_keypoints.json
#   inflating: /images_first_json/json_keypoints/1558_keypoints.json
#   inflating: /images_first_json/json_keypoints/1559_keypoints.json
#   inflating: /images_first_json/json_keypoints/155_keypoints.json
#   inflating: /images_first_json/json_keypoints/1560_keypoints.json
#   inflating: /images_first_json/json_keypoints/1561_keypoints.json
#   inflating: /images_first_json/json_keypoints/1562_keypoints.json
#   inflating: /images_first_json/json_keypoints/1563_keypoints.json
#   inflating: /images_first_json/json_keypoints/1564_keypoints.json
#   inflating: /images_first_json/json_keypoints/1565_keypoints.json
#   inflating: /images_first_json/json_keypoints/1566_keypoints.json
#   inflating: /images_first_json/json_keypoints/1567_keypoints.json
#   inflating: /images_first_json/json_keypoints/1568_keypoints.json
#   inflating: /images_first_json/json_keypoints/1569_keypoints.json
#   inflating: /images_first_json/json_keypoints/156_keypoints.json
#   inflating: /images_first_json/json_keypoints/1570_keypoints.json
#   inflating: /images_first_json/json_keypoints/1571_keypoints.json
#   inflating: /images_first_json/json_keypoints/1572_keypoints.json
#   inflating: /images_first_json/json_keypoints/1573_keypoints.json
#   inflating: /images_first_json/json_keypoints/1574_keypoints.json
#   inflating: /images_first_json/json_keypoints/1575_keypoints.json
#   inflating: /images_first_json/json_keypoints/1576_keypoints.json
#   inflating: /images_first_json/json_keypoints/1577_keypoints.json
#   inflating: /images_first_json/json_keypoints/1578_keypoints.json
#   inflating: /images_first_json/json_keypoints/1579_keypoints.json
#   inflating: /images_first_json/json_keypoints/157_keypoints.json
#   inflating: /images_first_json/json_keypoints/1580_keypoints.json
#   inflating: /images_first_json/json_keypoints/1581_keypoints.json
#   inflating: /images_first_json/json_keypoints/1582_keypoints.json
#   inflating: /images_first_json/json_keypoints/1583_keypoints.json
#   inflating: /images_first_json/json_keypoints/1584_keypoints.json
#   inflating: /images_first_json/json_keypoints/1585_keypoints.json
#   inflating: /images_first_json/json_keypoints/1586_keypoints.json
#   inflating: /images_first_json/json_keypoints/1587_keypoints.json
#   inflating: /images_first_json/json_keypoints/1588_keypoints.json
#   inflating: /images_first_json/json_keypoints/1589_keypoints.json
#   inflating: /images_first_json/json_keypoints/158_keypoints.json
#   inflating: /images_first_json/json_keypoints/1590_keypoints.json
#   inflating: /images_first_json/json_keypoints/1591_keypoints.json
#   inflating: /images_first_json/json_keypoints/1592_keypoints.json
#   inflating: /images_first_json/json_keypoints/1593_keypoints.json
#   inflating: /images_first_json/json_keypoints/1594_keypoints.json
#   inflating: /images_first_json/json_keypoints/1595_keypoints.json
#   inflating: /images_first_json/json_keypoints/1596_keypoints.json
#   inflating: /images_first_json/json_keypoints/1597_keypoints.json
#   inflating: /images_first_json/json_keypoints/1598_keypoints.json
#   inflating: /images_first_json/json_keypoints/1599_keypoints.json
#   inflating: /images_first_json/json_keypoints/159_keypoints.json
#   inflating: /images_first_json/json_keypoints/15_keypoints.json
#   inflating: /images_first_json/json_keypoints/1600_keypoints.json
#   inflating: /images_first_json/json_keypoints/1601_keypoints.json
#   inflating: /images_first_json/json_keypoints/1602_keypoints.json
#   inflating: /images_first_json/json_keypoints/1603_keypoints.json
#   inflating: /images_first_json/json_keypoints/1604_keypoints.json
#   inflating: /images_first_json/json_keypoints/1605_keypoints.json
#   inflating: /images_first_json/json_keypoints/1606_keypoints.json
#   inflating: /images_first_json/json_keypoints/1607_keypoints.json
#   inflating: /images_first_json/json_keypoints/1608_keypoints.json
#   inflating: /images_first_json/json_keypoints/1609_keypoints.json
#   inflating: /images_first_json/json_keypoints/160_keypoints.json
#   inflating: /images_first_json/json_keypoints/1610_keypoints.json
#   inflating: /images_first_json/json_keypoints/1611_keypoints.json
#   inflating: /images_first_json/json_keypoints/1612_keypoints.json
#   inflating: /images_first_json/json_keypoints/1613_keypoints.json
#   inflating: /images_first_json/json_keypoints/1614_keypoints.json
#   inflating: /images_first_json/json_keypoints/1615_keypoints.json
#   inflating: /images_first_json/json_keypoints/1616_keypoints.json
#   inflating: /images_first_json/json_keypoints/1617_keypoints.json
#   inflating: /images_first_json/json_keypoints/1618_keypoints.json
#   inflating: /images_first_json/json_keypoints/1619_keypoints.json
#   inflating: /images_first_json/json_keypoints/161_keypoints.json
#   inflating: /images_first_json/json_keypoints/1620_keypoints.json
#   inflating: /images_first_json/json_keypoints/1621_keypoints.json
#   inflating: /images_first_json/json_keypoints/1622_keypoints.json
#   inflating: /images_first_json/json_keypoints/1623_keypoints.json
#   inflating: /images_first_json/json_keypoints/1624_keypoints.json
#   inflating: /images_first_json/json_keypoints/1625_keypoints.json
#   inflating: /images_first_json/json_keypoints/1626_keypoints.json
# ...
#   inflating: /images_first_json/json_keypoints/790_keypoints.json
#   inflating: /images_first_json/json_keypoints/791_keypoints.json
#   inflating: /images_first_json/json_keypoints/792_keypoints.json
#   inflating: /images_first_json/json_keypoints/793_keypoints.json
#   inflating: /images_first_json/json_keypoints/794_keypoints.json
#   inflating: /images_first_json/json_keypoints/795_keypoints.json
#   inflating: /images_first_json/json_keypoints/796_keypoints.json
#   inflating: /images_first_json/json_keypoints/797_keypoints.json
#   inflating: /images_first_json/json_keypoints/798_keypoints.json
#   inflating: /images_first_json/json_keypoints/799_keypoints.json
#   inflating: /images_first_json/json_keypoints/79_keypoints.json
#   inflating: /images_first_json/json_keypoints/7_keypoints.json
#   inflating: /images_first_json/json_keypoints/800_keypoints.json
#   inflating: /images_first_json/json_keypoints/801_keypoints.json
#   inflating: /images_first_json/json_keypoints/802_keypoints.json
#   inflating: /images_first_json/json_keypoints/803_keypoints.json
#   inflating: /images_first_json/json_keypoints/804_keypoints.json
#   inflating: /images_first_json/json_keypoints/805_keypoints.json
#   inflating: /images_first_json/json_keypoints/806_keypoints.json
#   inflating: /images_first_json/json_keypoints/807_keypoints.json
#   inflating: /images_first_json/json_keypoints/808_keypoints.json
#   inflating: /images_first_json/json_keypoints/809_keypoints.json
#   inflating: /images_first_json/json_keypoints/80_keypoints.json
#   inflating: /images_first_json/json_keypoints/810_keypoints.json
#   inflating: /images_first_json/json_keypoints/811_keypoints.json
#   inflating: /images_first_json/json_keypoints/812_keypoints.json
#   inflating: /images_first_json/json_keypoints/813_keypoints.json
#   inflating: /images_first_json/json_keypoints/814_keypoints.json
#   inflating: /images_first_json/json_keypoints/815_keypoints.json
#   inflating: /images_first_json/json_keypoints/816_keypoints.json
#   inflating: /images_first_json/json_keypoints/817_keypoints.json
#   inflating: /images_first_json/json_keypoints/818_keypoints.json
#   inflating: /images_first_json/json_keypoints/819_keypoints.json
#   inflating: /images_first_json/json_keypoints/81_keypoints.json
#   inflating: /images_first_json/json_keypoints/820_keypoints.json
#   inflating: /images_first_json/json_keypoints/821_keypoints.json
#   inflating: /images_first_json/json_keypoints/822_keypoints.json
#   inflating: /images_first_json/json_keypoints/823_keypoints.json
#   inflating: /images_first_json/json_keypoints/824_keypoints.json
#   inflating: /images_first_json/json_keypoints/825_keypoints.json
#   inflating: /images_first_json/json_keypoints/826_keypoints.json
#   inflating: /images_first_json/json_keypoints/827_keypoints.json
#   inflating: /images_first_json/json_keypoints/828_keypoints.json
#   inflating: /images_first_json/json_keypoints/829_keypoints.json
#   inflating: /images_first_json/json_keypoints/82_keypoints.json
#   inflating: /images_first_json/json_keypoints/830_keypoints.json
#   inflating: /images_first_json/json_keypoints/831_keypoints.json
#   inflating: /images_first_json/json_keypoints/832_keypoints.json
#   inflating: /images_first_json/json_keypoints/833_keypoints.json
#   inflating: /images_first_json/json_keypoints/834_keypoints.json
#   inflating: /images_first_json/json_keypoints/835_keypoints.json
#   inflating: /images_first_json/json_keypoints/836_keypoints.json
#   inflating: /images_first_json/json_keypoints/837_keypoints.json
#   inflating: /images_first_json/json_keypoints/838_keypoints.json
#   inflating: /images_first_json/json_keypoints/839_keypoints.json
#   inflating: /images_first_json/json_keypoints/83_keypoints.json
#   inflating: /images_first_json/json_keypoints/840_keypoints.json
#   inflating: /images_first_json/json_keypoints/841_keypoints.json
#   inflating: /images_first_json/json_keypoints/842_keypoints.json
#   inflating: /images_first_json/json_keypoints/843_keypoints.json
#   inflating: /images_first_json/json_keypoints/844_keypoints.json
#   inflating: /images_first_json/json_keypoints/845_keypoints.json
#   inflating: /images_first_json/json_keypoints/846_keypoints.json
#   inflating: /images_first_json/json_keypoints/847_keypoints.json
#   inflating: /images_first_json/json_keypoints/848_keypoints.json
#   inflating: /images_first_json/json_keypoints/849_keypoints.json
#   inflating: /images_first_json/json_keypoints/84_keypoints.json
#   inflating: /images_first_json/json_keypoints/850_keypoints.json
#   inflating: /images_first_json/json_keypoints/851_keypoints.json
#   inflating: /images_first_json/json_keypoints/852_keypoints.json
#   inflating: /images_first_json/json_keypoints/853_keypoints.json
#   inflating: /images_first_json/json_keypoints/854_keypoints.json
#   inflating: /images_first_json/json_keypoints/855_keypoints.json
#   inflating: /images_first_json/json_keypoints/856_keypoints.json
#   inflating: /images_first_json/json_keypoints/857_keypoints.json
#   inflating: /images_first_json/json_keypoints/858_keypoints.json
#   inflating: /images_first_json/json_keypoints/859_keypoints.json
#   inflating: /images_first_json/json_keypoints/85_keypoints.json
#   inflating: /images_first_json/json_keypoints/860_keypoints.json
#   inflating: /images_first_json/json_keypoints/861_keypoints.json
#   inflating: /images_first_json/json_keypoints/862_keypoints.json
#   inflating: /images_first_json/json_keypoints/863_keypoints.json
#   inflating: /images_first_json/json_keypoints/864_keypoints.json
#   inflating: /images_first_json/json_keypoints/865_keypoints.json
#   inflating: /images_first_json/json_keypoints/866_keypoints.json
#   inflating: /images_first_json/json_keypoints/867_keypoints.json
#   inflating: /images_first_json/json_keypoints/868_keypoints.json
#   inflating: /images_first_json/json_keypoints/869_keypoints.json
#   inflating: /images_first_json/json_keypoints/86_keypoints.json
#   inflating: /images_first_json/json_keypoints/870_keypoints.json
#   inflating: /images_first_json/json_keypoints/871_keypoints.json
#   inflating: /images_first_json/json_keypoints/872_keypoints.json
#   inflating: /images_first_json/json_keypoints/873_keypoints.json
#   inflating: /images_first_json/json_keypoints/874_keypoints.json
#   inflating: /images_first_json/json_keypoints/875_keypoints.json
#   inflating: /images_first_json/json_keypoints/876_keypoints.json
#   inflating: /images_first_json/json_keypoints/877_keypoints.json
#   inflating: /images_first_json/json_keypoints/878_keypoints.json
#   inflating: /images_first_json/json_keypoints/879_keypoints.json
#   inflating: /images_first_json/json_keypoints/87_keypoints.json
#   inflating: /images_first_json/json_keypoints/880_keypoints.json
#   inflating: /images_first_json/json_keypoints/881_keypoints.json
#   inflating: /images_first_json/json_keypoints/882_keypoints.json
#   inflating: /images_first_json/json_keypoints/883_keypoints.json
#   inflating: /images_first_json/json_keypoints/884_keypoints.json
#   inflating: /images_first_json/json_keypoints/885_keypoints.json
#   inflating: /images_first_json/json_keypoints/886_keypoints.json
#   inflating: /images_first_json/json_keypoints/887_keypoints.json
#   inflating: /images_first_json/json_keypoints/888_keypoints.json
#   inflating: /images_first_json/json_keypoints/889_keypoints.json
#   inflating: /images_first_json/json_keypoints/88_keypoints.json
#   inflating: /images_first_json/json_keypoints/890_keypoints.json
#   inflating: /images_first_json/json_keypoints/891_keypoints.json
#   inflating: /images_first_json/json_keypoints/892_keypoints.json
#   inflating: /images_first_json/json_keypoints/893_keypoints.json
#   inflating: /images_first_json/json_keypoints/894_keypoints.json
#   inflating: /images_first_json/json_keypoints/895_keypoints.json
#   inflating: /images_first_json/json_keypoints/896_keypoints.json
#   inflating: /images_first_json/json_keypoints/897_keypoints.json
#   inflating: /images_first_json/json_keypoints/898_keypoints.json
#   inflating: /images_first_json/json_keypoints/899_keypoints.json
#   inflating: /images_first_json/json_keypoints/89_keypoints.json
#   inflating: /images_first_json/json_keypoints/8_keypoints.json
#   inflating: /images_first_json/json_keypoints/900_keypoints.json
#   inflating: /images_first_json/json_keypoints/901_keypoints.json
#   inflating: /images_first_json/json_keypoints/902_keypoints.json
#   inflating: /images_first_json/json_keypoints/903_keypoints.json
#   inflating: /images_first_json/json_keypoints/904_keypoints.json
#   inflating: /images_first_json/json_keypoints/905_keypoints.json
#   inflating: /images_first_json/json_keypoints/906_keypoints.json
#   inflating: /images_first_json/json_keypoints/907_keypoints.json
#   inflating: /images_first_json/json_keypoints/908_keypoints.json
#   inflating: /images_first_json/json_keypoints/909_keypoints.json
#   inflating: /images_first_json/json_keypoints/90_keypoints.json
#   inflating: /images_first_json/json_keypoints/910_keypoints.json
#   inflating: /images_first_json/json_keypoints/911_keypoints.json
#   inflating: /images_first_json/json_keypoints/912_keypoints.json
#   inflating: /images_first_json/json_keypoints/913_keypoints.json
#   inflating: /images_first_json/json_keypoints/914_keypoints.json
#   inflating: /images_first_json/json_keypoints/915_keypoints.json
#   inflating: /images_first_json/json_keypoints/916_keypoints.json
#   inflating: /images_first_json/json_keypoints/917_keypoints.json
#   inflating: /images_first_json/json_keypoints/918_keypoints.json
#   inflating: /images_first_json/json_keypoints/919_keypoints.json
#   inflating: /images_first_json/json_keypoints/91_keypoints.json
#   inflating: /images_first_json/json_keypoints/920_keypoints.json
#   inflating: /images_first_json/json_keypoints/921_keypoints.json
#   inflating: /images_first_json/json_keypoints/922_keypoints.json
#   inflating: /images_first_json/json_keypoints/923_keypoints.json
#   inflating: /images_first_json/json_keypoints/924_keypoints.json
#   inflating: /images_first_json/json_keypoints/925_keypoints.json
#   inflating: /images_first_json/json_keypoints/926_keypoints.json
#   inflating: /images_first_json/json_keypoints/927_keypoints.json
#   inflating: /images_first_json/json_keypoints/928_keypoints.json
#   inflating: /images_first_json/json_keypoints/929_keypoints.json
#   inflating: /images_first_json/json_keypoints/92_keypoints.json
#   inflating: /images_first_json/json_keypoints/930_keypoints.json
#   inflating: /images_first_json/json_keypoints/931_keypoints.json
#   inflating: /images_first_json/json_keypoints/932_keypoints.json
#   inflating: /images_first_json/json_keypoints/933_keypoints.json
#   inflating: /images_first_json/json_keypoints/934_keypoints.json
#   inflating: /images_first_json/json_keypoints/935_keypoints.json
#   inflating: /images_first_json/json_keypoints/936_keypoints.json
#   inflating: /images_first_json/json_keypoints/937_keypoints.json
#   inflating: /images_first_json/json_keypoints/938_keypoints.json
#   inflating: /images_first_json/json_keypoints/939_keypoints.json
#   inflating: /images_first_json/json_keypoints/93_keypoints.json
#   inflating: /images_first_json/json_keypoints/940_keypoints.json
#   inflating: /images_first_json/json_keypoints/941_keypoints.json
#   inflating: /images_first_json/json_keypoints/942_keypoints.json
#   inflating: /images_first_json/json_keypoints/943_keypoints.json
#   inflating: /images_first_json/json_keypoints/944_keypoints.json
#   inflating: /images_first_json/json_keypoints/945_keypoints.json
#   inflating: /images_first_json/json_keypoints/946_keypoints.json
#   inflating: /images_first_json/json_keypoints/947_keypoints.json
#   inflating: /images_first_json/json_keypoints/948_keypoints.json
#   inflating: /images_first_json/json_keypoints/949_keypoints.json
#   inflating: /images_first_json/json_keypoints/94_keypoints.json
#   inflating: /images_first_json/json_keypoints/950_keypoints.json
#   inflating: /images_first_json/json_keypoints/951_keypoints.json
#   inflating: /images_first_json/json_keypoints/952_keypoints.json
#   inflating: /images_first_json/json_keypoints/953_keypoints.json
#   inflating: /images_first_json/json_keypoints/954_keypoints.json
#   inflating: /images_first_json/json_keypoints/955_keypoints.json
#   inflating: /images_first_json/json_keypoints/956_keypoints.json
#   inflating: /images_first_json/json_keypoints/957_keypoints.json
#   inflating: /images_first_json/json_keypoints/958_keypoints.json
#   inflating: /images_first_json/json_keypoints/959_keypoints.json
#   inflating: /images_first_json/json_keypoints/95_keypoints.json
#   inflating: /images_first_json/json_keypoints/960_keypoints.json
#   inflating: /images_first_json/json_keypoints/961_keypoints.json
#   inflating: /images_first_json/json_keypoints/962_keypoints.json
#   inflating: /images_first_json/json_keypoints/963_keypoints.json
#   inflating: /images_first_json/json_keypoints/964_keypoints.json
#   inflating: /images_first_json/json_keypoints/965_keypoints.json
#   inflating: /images_first_json/json_keypoints/966_keypoints.json
#   inflating: /images_first_json/json_keypoints/967_keypoints.json
#   inflating: /images_first_json/json_keypoints/968_keypoints.json
#   inflating: /images_first_json/json_keypoints/969_keypoints.json
#   inflating: /images_first_json/json_keypoints/96_keypoints.json
#   inflating: /images_first_json/json_keypoints/970_keypoints.json
#   inflating: /images_first_json/json_keypoints/971_keypoints.json
#   inflating: /images_first_json/json_keypoints/972_keypoints.json
#   inflating: /images_first_json/json_keypoints/973_keypoints.json
#   inflating: /images_first_json/json_keypoints/974_keypoints.json
#   inflating: /images_first_json/json_keypoints/975_keypoints.json
#   inflating: /images_first_json/json_keypoints/976_keypoints.json
#   inflating: /images_first_json/json_keypoints/977_keypoints.json
#   inflating: /images_first_json/json_keypoints/978_keypoints.json
#   inflating: /images_first_json/json_keypoints/979_keypoints.json
#   inflating: /images_first_json/json_keypoints/97_keypoints.json
#   inflating: /images_first_json/json_keypoints/980_keypoints.json
#   inflating: /images_first_json/json_keypoints/981_keypoints.json
#   inflating: /images_first_json/json_keypoints/982_keypoints.json
#   inflating: /images_first_json/json_keypoints/983_keypoints.json
#   inflating: /images_first_json/json_keypoints/984_keypoints.json
#   inflating: /images_first_json/json_keypoints/985_keypoints.json
#   inflating: /images_first_json/json_keypoints/986_keypoints.json
#   inflating: /images_first_json/json_keypoints/987_keypoints.json
#   inflating: /images_first_json/json_keypoints/988_keypoints.json
#   inflating: /images_first_json/json_keypoints/989_keypoints.json
#   inflating: /images_first_json/json_keypoints/98_keypoints.json
#   inflating: /images_first_json/json_keypoints/990_keypoints.json
#   inflating: /images_first_json/json_keypoints/991_keypoints.json
#   inflating: /images_first_json/json_keypoints/992_keypoints.json
#   inflating: /images_first_json/json_keypoints/993_keypoints.json
#   inflating: /images_first_json/json_keypoints/994_keypoints.json
#   inflating: /images_first_json/json_keypoints/995_keypoints.json
#   inflating: /images_first_json/json_keypoints/996_keypoints.json
#   inflating: /images_first_json/json_keypoints/997_keypoints.json
#   inflating: /images_first_json/json_keypoints/998_keypoints.json
#   inflating: /images_first_json/json_keypoints/999_keypoints.json
#   inflating: /images_first_json/json_keypoints/99_keypoints.json
#   inflating: /images_first_json/json_keypoints/9_keypoints.json
#   inflating: /images_first_json/json_keypoints/f'{video_name}_keypoints.json

# %% [markdown]
# Need to get data in format of list of dataframe being the data where the index is same as label index.

# %%
# Getting all the files for data
files = glob.glob('/images_first_json/json_keypoints/*')

# Getting the sheet of the signs
iso_sign_key = pd.read_excel('Isolated_Sign_Language_List.xlsx', index_col=None, usecols="B:D")

# check start time
start = time.time()

# Initialising the array for the test & train data
y_train = []
x_train = []

y_test = []
x_test = []

# Getting largest frames in the dataset to match all sizes
largest_frames = 0

# Going through all files
for file in files:
  # Getting JSON file
  with open(file, 'r') as f:
    # Reading JSON file and converting it to dict type
    d = f.read()
    vid_data = json.loads(d)

    # Getting video id to match with the name
    id = file.split("/")[-1].split('_')[0]
    id = 1 if id == "f'{video" else id # Checker for missing video id 1

    # Get Key points in dataframe format for the next step
    data = []
    for frame in vid_data:
        # Checks if not all the land_marks are there, skip frame if yes
        if not check_list_contained(['pose_landmarks', 'left_hand_landmarks', 'right_hand_landmarks'], frame.keys()):
          #print('failed', frame['frame'])
          continue

        # Appending whole frame data to the temp variable
        f_data = pd.DataFrame(frame['pose_landmarks'] + frame['left_hand_landmarks'] + frame['right_hand_landmarks'])
        data.append(f_data)

    if len(data) == 0:
      # print(f"No complete data for {id}")
      continue

    # Making the dataframes in the same format
    combined_df = pd.concat(data, ignore_index=True)
    reshaped_data = combined_df.values.reshape((len(data), 75, 4))

    # Checking for largest frame
    largest_frames = len(data) if len(data) > largest_frames else largest_frames

    # Read the csv for the label and which split is goes into
    iso_row = iso_sign_key.loc[iso_sign_key['Video_ID'] == int(id)]
    word = iso_row["Gloss"].values[0]

    # cbs createing val data, only checking for test
    if "test" in iso_row["Split"].values:
      y_test.append(word)
      x_test.append(reshaped_data)
    else:
      y_train.append(word)
      x_train.append(reshaped_data)

# Printing total data and total time run
print("Train", len(x_train), len(y_train))
print("Test", len(x_test), len(y_test))
print(time.time() - start)
# Out:
# Train 2522 2522
# Test 587 587
# 36.967543601989746

# %%
print(x_train[5].shape)
print(len(x_train))
print(largest_frames)
# Out:
# (13, 75, 4)
# 2522
# 136

# %%
def pad_sequences(data, max_timesteps):
    padded_data = []

    for sequence in data:
        # Original shape: (timesteps, keypoints, 4)
        timesteps, keypoints, features = sequence.shape

        # Reshape the keypoints (75) into spatial dimensions for Conv3D
        height = 75  # Assuming a square grid-like reshaping, for example 15x5
        width = keypoints // height

        # Reshape sequence to fit into Conv3D: (timesteps, height, width, features)
        reshaped_sequence = sequence.reshape((timesteps, height, width, features))

        # Pad the sequence along the time axis (first dimension)
        padding_needed = max_timesteps - timesteps
        if padding_needed > 0:
            # Pad along the time dimension (axis 0)
            padded_sequence = np.pad(reshaped_sequence, ((0, padding_needed), (0, 0), (0, 0), (0, 0)), mode='constant')
        else:
            padded_sequence = reshaped_sequence

        padded_data.append(padded_sequence)

    # Convert to a numpy array and add the required extra channel dimension for Conv3D
    return np.array(padded_data)[..., np.newaxis]

# Pad train and test data
padded_train_data = pad_sequences(x_train, largest_frames)
padded_test_data = pad_sequences(x_test, largest_frames)

# padded_train_data = padded_train_data[..., np.newaxis]
# padded_test_data = padded_test_data[..., np.newaxis]

# %%
# [Video [Frame [Keypoints]]]
print(padded_train_data.shape)
print(padded_test_data.shape)

timesteps, height, width, channels, outputs = padded_train_data.shape[1], padded_train_data.shape[2], padded_train_data.shape[3], padded_train_data.shape[4], 610
# Out:
# (2522, 136, 75, 1, 4, 1)
# (587, 136, 75, 1, 4, 1)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)

# Encode the labels (train and test labels)
train_labels = label_encoder.transform(y_train)  # Assuming these are your training labels
test_labels = label_encoder.transform(y_test)  # Assuming this is your test label

# One-hot encode the labels for use in categorical crossentropy
train_labels = to_categorical(train_labels, num_classes=outputs)
test_labels = to_categorical(test_labels, num_classes=outputs)

# %%
load_weights = "/content/gdrive/MyDrive/Auslan App/Data/frienddidit.keras"
# load_weights = None
if load_weights == None:
  # Define the model
  input_layer = Input(shape=(136, 75, 1, 4))  # Adjust shape based on your data

  # 3D Convolutional layers to extract features over time
  x = TimeDistributed(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'))(input_layer)
  x = TimeDistributed(BatchNormalization())(x)
  x = TimeDistributed(Flatten())(x)

  # LSTM for temporal processing
  x = Bidirectional(LSTM(128, return_sequences=False))(x)

  # Add Dropout for regularization
  x = Dropout(0.5)(x)

  # Fully connected layers for classification
  x = Dense(256, activation='relu')(x)
  x = Dropout(0.5)(x)
  output = Dense(610, activation='softmax')(x)  # Assuming 610 output classes

  # Create the final model
  final_model = Model(inputs=input_layer, outputs=output)

  # Compile the model with a lower learning rate
  final_model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

  # Summary of the model
  final_model.summary()

else:
  final_model = load_model(filepath=load_weights)
  final_model.summary()
# Out:
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_18 (InputLayer)          │ (None, 136, 75, 1, 4)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_33                  │ (None, 136, 75, 1, 32)      │           1,184 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_34                  │ (None, 136, 75, 1, 32)      │             128 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_35                  │ (None, 136, 2400)           │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 256)                 │       2,589,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 610)                 │         156,770 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,440,584 (32.20 MB)
#  Trainable params: 2,813,506 (10.73 MB)
#  Non-trainable params: 64 (256.00 B)
#  Optimizer params: 5,627,014 (21.47 MB)

# %%
# Callback Functions:

# 1. Early Stopping: Stops training when a monitored metric has stopped improving, which helps to avoid overfitting.
early_stopping = EarlyStopping (
    monitor = 'val_accuracy', # Monitor validation loss
    patience = 10, # Number of epochs with no improvement after which training will be stopped
    verbose = 1, # Print messages
    restore_best_weights = True # Restore model weights from the epoch with the best validation loss
)

# 2. Model Checkpoint: Saves the model at specific intervals or when it achieves the best performance on the validation set.
model_checkpoint = ModelCheckpoint(
    filepath = '/content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras',
    monitor = 'val_accuracy',
    save_best_only = True,
    verbose = 1
)

#3. Learning Rate Scheduler: Reduces the learning rate when the performance metric stops improving.
reduce_lr = ReduceLROnPlateau(
    monitor = 'val_loss',
    factor = 0.2, # Factor by which the learning rate will be reduced
    patience = 10,
    verbose = 1
)

callbacks = [model_checkpoint]

# %%
# Train model
history = final_model.fit(
    padded_train_data,
    train_labels,
    epochs=125,  # Adjust epochs based on your needs
    batch_size=8,  # You can adjust this depending on memory
    validation_data=(padded_test_data, test_labels),
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.2998 - loss: 2.9928
# Epoch 1: val_accuracy improved from -inf to 0.02555, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 117ms/step - accuracy: 0.2997 - loss: 2.9929 - val_accuracy: 0.0256 - val_loss: 6.7726
# Epoch 2/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3056 - loss: 2.9167
# Epoch 2: val_accuracy improved from 0.02555 to 0.05111, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.3056 - loss: 2.9170 - val_accuracy: 0.0511 - val_loss: 6.6997
# Epoch 3/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.2779 - loss: 2.9726
# Epoch 3: val_accuracy did not improve from 0.05111
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.2779 - loss: 2.9728 - val_accuracy: 0.0426 - val_loss: 6.6166
# Epoch 4/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.2862 - loss: 3.0165
# Epoch 4: val_accuracy did not improve from 0.05111
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.2862 - loss: 3.0165 - val_accuracy: 0.0460 - val_loss: 6.6722
# Epoch 5/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3061 - loss: 2.9510
# Epoch 5: val_accuracy did not improve from 0.05111
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 116ms/step - accuracy: 0.3060 - loss: 2.9510 - val_accuracy: 0.0443 - val_loss: 6.7005
# Epoch 6/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3050 - loss: 2.8295
# Epoch 6: val_accuracy improved from 0.05111 to 0.06303, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 42s 118ms/step - accuracy: 0.3050 - loss: 2.8298 - val_accuracy: 0.0630 - val_loss: 6.7428
# Epoch 7/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3144 - loss: 2.8759
# Epoch 7: val_accuracy did not improve from 0.06303
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3144 - loss: 2.8759 - val_accuracy: 0.0392 - val_loss: 6.6679
# Epoch 8/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3190 - loss: 2.8707
# Epoch 8: val_accuracy did not improve from 0.06303
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3190 - loss: 2.8707 - val_accuracy: 0.0494 - val_loss: 6.6793
# Epoch 9/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3061 - loss: 2.8280
# Epoch 9: val_accuracy did not improve from 0.06303
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3061 - loss: 2.8280 - val_accuracy: 0.0460 - val_loss: 6.6489
# Epoch 10/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3014 - loss: 2.7997
# Epoch 10: val_accuracy improved from 0.06303 to 0.06985, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3014 - loss: 2.7999 - val_accuracy: 0.0698 - val_loss: 6.6697
# Epoch 11/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3215 - loss: 2.7808
# Epoch 11: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 42s 119ms/step - accuracy: 0.3215 - loss: 2.7808 - val_accuracy: 0.0545 - val_loss: 6.6447
# Epoch 12/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.3152 - loss: 2.7459
# Epoch 12: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 116ms/step - accuracy: 0.3151 - loss: 2.7462 - val_accuracy: 0.0443 - val_loss: 6.6581
# Epoch 13/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3285 - loss: 2.7872
# Epoch 13: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3285 - loss: 2.7873 - val_accuracy: 0.0511 - val_loss: 6.8429
# Epoch 14/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3230 - loss: 2.7859
# Epoch 14: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3230 - loss: 2.7859 - val_accuracy: 0.0460 - val_loss: 6.6988
# Epoch 15/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3356 - loss: 2.7102
# Epoch 15: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3356 - loss: 2.7103 - val_accuracy: 0.0630 - val_loss: 6.7428
# Epoch 16/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3426 - loss: 2.6750
# Epoch 16: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.3425 - loss: 2.6752 - val_accuracy: 0.0630 - val_loss: 6.7320
# Epoch 17/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3250 - loss: 2.7022
# Epoch 17: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 116ms/step - accuracy: 0.3251 - loss: 2.7022 - val_accuracy: 0.0698 - val_loss: 6.7919
# Epoch 18/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3240 - loss: 2.6951
# Epoch 18: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 118ms/step - accuracy: 0.3240 - loss: 2.6951 - val_accuracy: 0.0681 - val_loss: 6.6112
# Epoch 19/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3364 - loss: 2.7213
# Epoch 19: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 119ms/step - accuracy: 0.3364 - loss: 2.7213 - val_accuracy: 0.0579 - val_loss: 6.7233
# Epoch 20/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3647 - loss: 2.5940
# Epoch 20: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.3646 - loss: 2.5942 - val_accuracy: 0.0681 - val_loss: 6.7967
# Epoch 21/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3646 - loss: 2.5546
# Epoch 21: val_accuracy did not improve from 0.06985
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.3646 - loss: 2.5547 - val_accuracy: 0.0681 - val_loss: 6.7485
# Epoch 22/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3374 - loss: 2.6002
# Epoch 22: val_accuracy improved from 0.06985 to 0.08007, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.3374 - loss: 2.6002 - val_accuracy: 0.0801 - val_loss: 6.7105
# Epoch 23/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.3791 - loss: 2.5556
# Epoch 23: val_accuracy improved from 0.08007 to 0.08859, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.3791 - loss: 2.5557 - val_accuracy: 0.0886 - val_loss: 6.6505
# Epoch 24/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3652 - loss: 2.5236
# Epoch 24: val_accuracy improved from 0.08859 to 0.09370, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.3651 - loss: 2.5237 - val_accuracy: 0.0937 - val_loss: 6.8301
# Epoch 25/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3515 - loss: 2.6231
# Epoch 25: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.3515 - loss: 2.6230 - val_accuracy: 0.0869 - val_loss: 6.7243
# Epoch 26/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3670 - loss: 2.5338
# Epoch 26: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.3670 - loss: 2.5338 - val_accuracy: 0.0681 - val_loss: 6.8043
# Epoch 27/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3762 - loss: 2.5007
# Epoch 27: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 116ms/step - accuracy: 0.3762 - loss: 2.5008 - val_accuracy: 0.0784 - val_loss: 6.8863
# Epoch 28/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3750 - loss: 2.4864
# Epoch 28: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3750 - loss: 2.4863 - val_accuracy: 0.0869 - val_loss: 6.8141
# Epoch 29/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3918 - loss: 2.4124
# Epoch 29: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3918 - loss: 2.4125 - val_accuracy: 0.0886 - val_loss: 6.7115
# Epoch 30/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3941 - loss: 2.3885
# Epoch 30: val_accuracy did not improve from 0.09370
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3940 - loss: 2.3887 - val_accuracy: 0.0886 - val_loss: 6.7233
# Epoch 31/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3839 - loss: 2.4104
# Epoch 31: val_accuracy improved from 0.09370 to 0.09540, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3839 - loss: 2.4105 - val_accuracy: 0.0954 - val_loss: 6.7374
# Epoch 32/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3868 - loss: 2.4493
# Epoch 32: val_accuracy did not improve from 0.09540
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.3868 - loss: 2.4493 - val_accuracy: 0.0903 - val_loss: 6.6881
# Epoch 33/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3915 - loss: 2.3705
# Epoch 33: val_accuracy did not improve from 0.09540
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.3915 - loss: 2.3706 - val_accuracy: 0.0937 - val_loss: 6.7807
# Epoch 34/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3830 - loss: 2.3773
# Epoch 34: val_accuracy did not improve from 0.09540
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.3830 - loss: 2.3774 - val_accuracy: 0.0920 - val_loss: 6.7698
# Epoch 35/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4058 - loss: 2.3499
# Epoch 35: val_accuracy improved from 0.09540 to 0.09881, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4058 - loss: 2.3499 - val_accuracy: 0.0988 - val_loss: 6.8604
# Epoch 36/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4115 - loss: 2.2890
# Epoch 36: val_accuracy improved from 0.09881 to 0.10051, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4115 - loss: 2.2891 - val_accuracy: 0.1005 - val_loss: 6.8680
# Epoch 37/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4212 - loss: 2.2379
# Epoch 37: val_accuracy improved from 0.10051 to 0.10221, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - accuracy: 0.4211 - loss: 2.2381 - val_accuracy: 0.1022 - val_loss: 6.9468
# Epoch 38/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4152 - loss: 2.2648
# Epoch 38: val_accuracy improved from 0.10221 to 0.11755, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 39s 122ms/step - accuracy: 0.4152 - loss: 2.2648 - val_accuracy: 0.1175 - val_loss: 6.9228
# Epoch 39/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3951 - loss: 2.3130
# Epoch 39: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.3951 - loss: 2.3130 - val_accuracy: 0.0920 - val_loss: 6.9778
# Epoch 40/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4297 - loss: 2.2071
# Epoch 40: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.4296 - loss: 2.2074 - val_accuracy: 0.1141 - val_loss: 6.8569
# Epoch 41/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4297 - loss: 2.2316
# Epoch 41: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.4297 - loss: 2.2317 - val_accuracy: 0.1175 - val_loss: 7.0004
# Epoch 42/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4052 - loss: 2.2576
# Epoch 42: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4052 - loss: 2.2577 - val_accuracy: 0.1056 - val_loss: 7.1513
# Epoch 43/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4308 - loss: 2.1440
# Epoch 43: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 117ms/step - accuracy: 0.4308 - loss: 2.1440 - val_accuracy: 0.1005 - val_loss: 7.0302
# Epoch 44/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4370 - loss: 2.1743
# Epoch 44: val_accuracy did not improve from 0.11755
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.4370 - loss: 2.1744 - val_accuracy: 0.1039 - val_loss: 6.9715
# Epoch 45/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4528 - loss: 2.1569
# Epoch 45: val_accuracy improved from 0.11755 to 0.13288, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4528 - loss: 2.1569 - val_accuracy: 0.1329 - val_loss: 6.9657
# Epoch 46/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4547 - loss: 2.1632
# Epoch 46: val_accuracy did not improve from 0.13288
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4546 - loss: 2.1632 - val_accuracy: 0.1124 - val_loss: 7.0027
# Epoch 47/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4695 - loss: 2.0891
# Epoch 47: val_accuracy did not improve from 0.13288
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4695 - loss: 2.0892 - val_accuracy: 0.1193 - val_loss: 7.1403
# Epoch 48/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4562 - loss: 2.0670
# Epoch 48: val_accuracy improved from 0.13288 to 0.14480, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4562 - loss: 2.0672 - val_accuracy: 0.1448 - val_loss: 7.2180
# Epoch 49/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4182 - loss: 2.1972
# Epoch 49: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4182 - loss: 2.1970 - val_accuracy: 0.1261 - val_loss: 7.1337
# Epoch 50/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4704 - loss: 2.0998
# Epoch 50: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4704 - loss: 2.0999 - val_accuracy: 0.1227 - val_loss: 7.0372
# Epoch 51/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4571 - loss: 2.0537
# Epoch 51: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4571 - loss: 2.0538 - val_accuracy: 0.1363 - val_loss: 7.0085
# Epoch 52/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4613 - loss: 2.0469
# Epoch 52: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.4613 - loss: 2.0470 - val_accuracy: 0.1278 - val_loss: 7.3050
# Epoch 53/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4547 - loss: 2.1212
# Epoch 53: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4547 - loss: 2.1210 - val_accuracy: 0.1193 - val_loss: 7.1637
# Epoch 54/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4611 - loss: 2.0303
# Epoch 54: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 116ms/step - accuracy: 0.4611 - loss: 2.0303 - val_accuracy: 0.1346 - val_loss: 7.2414
# Epoch 55/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4808 - loss: 2.0014
# Epoch 55: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4808 - loss: 2.0014 - val_accuracy: 0.1329 - val_loss: 7.3217
# Epoch 56/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4732 - loss: 1.9991
# Epoch 56: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 117ms/step - accuracy: 0.4731 - loss: 1.9993 - val_accuracy: 0.1278 - val_loss: 7.4067
# Epoch 57/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4441 - loss: 2.0564
# Epoch 57: val_accuracy did not improve from 0.14480
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4441 - loss: 2.0563 - val_accuracy: 0.1431 - val_loss: 7.1835
# Epoch 58/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4778 - loss: 1.9616
# Epoch 58: val_accuracy improved from 0.14480 to 0.14991, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.4778 - loss: 1.9617 - val_accuracy: 0.1499 - val_loss: 7.1558
# Epoch 59/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4518 - loss: 1.9712
# Epoch 59: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 117ms/step - accuracy: 0.4518 - loss: 1.9712 - val_accuracy: 0.1380 - val_loss: 7.0877
# Epoch 60/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4686 - loss: 2.0006
# Epoch 60: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4686 - loss: 2.0006 - val_accuracy: 0.1312 - val_loss: 7.2453
# Epoch 61/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4930 - loss: 1.8796
# Epoch 61: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.4929 - loss: 1.8798 - val_accuracy: 0.1363 - val_loss: 7.3747
# Epoch 62/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5095 - loss: 1.8980
# Epoch 62: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 117ms/step - accuracy: 0.5095 - loss: 1.8981 - val_accuracy: 0.1397 - val_loss: 7.1061
# Epoch 63/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4900 - loss: 1.9263
# Epoch 63: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.4900 - loss: 1.9263 - val_accuracy: 0.1465 - val_loss: 7.2221
# Epoch 64/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5014 - loss: 1.9018
# Epoch 64: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5014 - loss: 1.9019 - val_accuracy: 0.1380 - val_loss: 7.0927
# Epoch 65/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5180 - loss: 1.8404
# Epoch 65: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5179 - loss: 1.8405 - val_accuracy: 0.1397 - val_loss: 7.3452
# Epoch 66/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4981 - loss: 1.8831
# Epoch 66: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.4981 - loss: 1.8830 - val_accuracy: 0.1448 - val_loss: 7.2492
# Epoch 67/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4941 - loss: 1.8392
# Epoch 67: val_accuracy did not improve from 0.14991
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.4941 - loss: 1.8394 - val_accuracy: 0.1448 - val_loss: 7.2672
# Epoch 68/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5009 - loss: 1.7985
# Epoch 68: val_accuracy improved from 0.14991 to 0.15843, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5009 - loss: 1.7987 - val_accuracy: 0.1584 - val_loss: 7.2163
# Epoch 69/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5176 - loss: 1.8015
# Epoch 69: val_accuracy did not improve from 0.15843
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5176 - loss: 1.8016 - val_accuracy: 0.1516 - val_loss: 7.1197
# Epoch 70/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5176 - loss: 1.8324
# Epoch 70: val_accuracy did not improve from 0.15843
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5176 - loss: 1.8324 - val_accuracy: 0.1261 - val_loss: 7.2301
# Epoch 71/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5200 - loss: 1.7639
# Epoch 71: val_accuracy improved from 0.15843 to 0.16014, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 42s 121ms/step - accuracy: 0.5200 - loss: 1.7641 - val_accuracy: 0.1601 - val_loss: 7.1454
# Epoch 72/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5220 - loss: 1.7518
# Epoch 72: val_accuracy did not improve from 0.16014
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 118ms/step - accuracy: 0.5220 - loss: 1.7520 - val_accuracy: 0.1482 - val_loss: 7.2547
# Epoch 73/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5446 - loss: 1.7238
# Epoch 73: val_accuracy did not improve from 0.16014
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5446 - loss: 1.7239 - val_accuracy: 0.1516 - val_loss: 7.2360
# Epoch 74/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5434 - loss: 1.7321
# Epoch 74: val_accuracy did not improve from 0.16014
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5433 - loss: 1.7322 - val_accuracy: 0.1465 - val_loss: 7.3853
# Epoch 75/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5145 - loss: 1.7884
# Epoch 75: val_accuracy did not improve from 0.16014
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5145 - loss: 1.7884 - val_accuracy: 0.1601 - val_loss: 7.2582
# Epoch 76/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5144 - loss: 1.7482
# Epoch 76: val_accuracy did not improve from 0.16014
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5144 - loss: 1.7484 - val_accuracy: 0.1499 - val_loss: 7.3617
# Epoch 77/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5624 - loss: 1.6149
# Epoch 77: val_accuracy improved from 0.16014 to 0.16525, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5623 - loss: 1.6151 - val_accuracy: 0.1652 - val_loss: 7.4600
# Epoch 78/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5519 - loss: 1.6567
# Epoch 78: val_accuracy did not improve from 0.16525
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5518 - loss: 1.6569 - val_accuracy: 0.1618 - val_loss: 7.4415
# Epoch 79/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5337 - loss: 1.7272
# Epoch 79: val_accuracy did not improve from 0.16525
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 119ms/step - accuracy: 0.5337 - loss: 1.7272 - val_accuracy: 0.1635 - val_loss: 7.5347
# Epoch 80/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5335 - loss: 1.7232
# Epoch 80: val_accuracy did not improve from 0.16525
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5335 - loss: 1.7232 - val_accuracy: 0.1618 - val_loss: 7.5681
# Epoch 81/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5509 - loss: 1.6406
# Epoch 81: val_accuracy did not improve from 0.16525
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - accuracy: 0.5509 - loss: 1.6408 - val_accuracy: 0.1652 - val_loss: 7.5677
# Epoch 82/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5478 - loss: 1.6256
# Epoch 82: val_accuracy did not improve from 0.16525
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5478 - loss: 1.6257 - val_accuracy: 0.1618 - val_loss: 7.5216
# Epoch 83/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5614 - loss: 1.6295
# Epoch 83: val_accuracy improved from 0.16525 to 0.17036, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.5614 - loss: 1.6296 - val_accuracy: 0.1704 - val_loss: 7.6086
# Epoch 84/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5402 - loss: 1.6808
# Epoch 84: val_accuracy did not improve from 0.17036
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.5402 - loss: 1.6807 - val_accuracy: 0.1584 - val_loss: 7.3380
# Epoch 85/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5567 - loss: 1.5876
# Epoch 85: val_accuracy did not improve from 0.17036
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5567 - loss: 1.5877 - val_accuracy: 0.1567 - val_loss: 7.3171
# Epoch 86/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5492 - loss: 1.5892
# Epoch 86: val_accuracy did not improve from 0.17036
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 117ms/step - accuracy: 0.5493 - loss: 1.5893 - val_accuracy: 0.1635 - val_loss: 7.4581
# Epoch 87/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5434 - loss: 1.5828
# Epoch 87: val_accuracy did not improve from 0.17036
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 43s 123ms/step - accuracy: 0.5434 - loss: 1.5828 - val_accuracy: 0.1567 - val_loss: 7.5349
# Epoch 88/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5579 - loss: 1.5932
# Epoch 88: val_accuracy did not improve from 0.17036
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 57s 181ms/step - accuracy: 0.5579 - loss: 1.5932 - val_accuracy: 0.1618 - val_loss: 7.4427
# Epoch 89/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5903 - loss: 1.5043
# Epoch 89: val_accuracy improved from 0.17036 to 0.17547, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 64s 124ms/step - accuracy: 0.5902 - loss: 1.5045 - val_accuracy: 0.1755 - val_loss: 7.3604
# Epoch 90/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5821 - loss: 1.5741
# Epoch 90: val_accuracy improved from 0.17547 to 0.17717, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.5821 - loss: 1.5742 - val_accuracy: 0.1772 - val_loss: 7.3417
# Epoch 91/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5878 - loss: 1.5143
# Epoch 91: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 122ms/step - accuracy: 0.5878 - loss: 1.5144 - val_accuracy: 0.1772 - val_loss: 7.4199
# Epoch 92/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5645 - loss: 1.5723
# Epoch 92: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.5646 - loss: 1.5723 - val_accuracy: 0.1755 - val_loss: 7.4219
# Epoch 93/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5983 - loss: 1.4339
# Epoch 93: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.5983 - loss: 1.4341 - val_accuracy: 0.1635 - val_loss: 7.6033
# Epoch 94/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5720 - loss: 1.4873
# Epoch 94: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 37s 118ms/step - accuracy: 0.5720 - loss: 1.4875 - val_accuracy: 0.1687 - val_loss: 7.4853
# Epoch 95/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5831 - loss: 1.4831
# Epoch 95: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 118ms/step - accuracy: 0.5831 - loss: 1.4832 - val_accuracy: 0.1738 - val_loss: 7.6596
# Epoch 96/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5724 - loss: 1.4989
# Epoch 96: val_accuracy did not improve from 0.17717
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5724 - loss: 1.4989 - val_accuracy: 0.1687 - val_loss: 7.7317
# Epoch 97/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5978 - loss: 1.4578
# Epoch 97: val_accuracy improved from 0.17717 to 0.18569, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5978 - loss: 1.4579 - val_accuracy: 0.1857 - val_loss: 7.4692
# Epoch 98/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5913 - loss: 1.4495
# Epoch 98: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.5913 - loss: 1.4497 - val_accuracy: 0.1652 - val_loss: 7.6579
# Epoch 99/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6152 - loss: 1.3713
# Epoch 99: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - accuracy: 0.6151 - loss: 1.3715 - val_accuracy: 0.1755 - val_loss: 7.5902
# Epoch 100/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5958 - loss: 1.3994
# Epoch 100: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.5957 - loss: 1.3996 - val_accuracy: 0.1789 - val_loss: 7.5654
# Epoch 101/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5997 - loss: 1.4280
# Epoch 101: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.5997 - loss: 1.4280 - val_accuracy: 0.1738 - val_loss: 7.7331
# Epoch 102/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5933 - loss: 1.4031
# Epoch 102: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.5933 - loss: 1.4032 - val_accuracy: 0.1772 - val_loss: 7.6625
# Epoch 103/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5943 - loss: 1.4488
# Epoch 103: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.5943 - loss: 1.4489 - val_accuracy: 0.1789 - val_loss: 7.5235
# Epoch 104/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6060 - loss: 1.4319
# Epoch 104: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.6060 - loss: 1.4319 - val_accuracy: 0.1738 - val_loss: 7.6503
# Epoch 105/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6123 - loss: 1.3746
# Epoch 105: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.6122 - loss: 1.3749 - val_accuracy: 0.1704 - val_loss: 7.7662
# Epoch 106/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6177 - loss: 1.3528
# Epoch 106: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.6177 - loss: 1.3528 - val_accuracy: 0.1840 - val_loss: 7.7902
# Epoch 107/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6206 - loss: 1.3130
# Epoch 107: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 119ms/step - accuracy: 0.6206 - loss: 1.3131 - val_accuracy: 0.1687 - val_loss: 7.7461
# Epoch 108/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6061 - loss: 1.4280
# Epoch 108: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.6061 - loss: 1.4280 - val_accuracy: 0.1806 - val_loss: 7.7189
# Epoch 109/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6222 - loss: 1.3536
# Epoch 109: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.6222 - loss: 1.3537 - val_accuracy: 0.1721 - val_loss: 7.8702
# Epoch 110/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6160 - loss: 1.3218
# Epoch 110: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - accuracy: 0.6159 - loss: 1.3220 - val_accuracy: 0.1789 - val_loss: 7.6840
# Epoch 111/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6284 - loss: 1.3556
# Epoch 111: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.6283 - loss: 1.3557 - val_accuracy: 0.1772 - val_loss: 7.8786
# Epoch 112/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6248 - loss: 1.3024
# Epoch 112: val_accuracy did not improve from 0.18569
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.6248 - loss: 1.3025 - val_accuracy: 0.1857 - val_loss: 7.9053
# Epoch 113/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6483 - loss: 1.3037
# Epoch 113: val_accuracy improved from 0.18569 to 0.18739, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.6482 - loss: 1.3039 - val_accuracy: 0.1874 - val_loss: 7.7886
# Epoch 114/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6309 - loss: 1.2961
# Epoch 114: val_accuracy improved from 0.18739 to 0.18910, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.6309 - loss: 1.2962 - val_accuracy: 0.1891 - val_loss: 7.9425
# Epoch 115/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6281 - loss: 1.3246
# Epoch 115: val_accuracy improved from 0.18910 to 0.19591, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 42s 124ms/step - accuracy: 0.6281 - loss: 1.3246 - val_accuracy: 0.1959 - val_loss: 7.9965
# Epoch 116/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6303 - loss: 1.3146
# Epoch 116: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 120ms/step - accuracy: 0.6303 - loss: 1.3146 - val_accuracy: 0.1942 - val_loss: 7.9507
# Epoch 117/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6443 - loss: 1.2561
# Epoch 117: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.6442 - loss: 1.2562 - val_accuracy: 0.1942 - val_loss: 7.9813
# Epoch 118/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6214 - loss: 1.3258
# Epoch 118: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 39s 122ms/step - accuracy: 0.6214 - loss: 1.3257 - val_accuracy: 0.1908 - val_loss: 8.0772
# Epoch 119/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6334 - loss: 1.2643
# Epoch 119: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 39s 123ms/step - accuracy: 0.6334 - loss: 1.2645 - val_accuracy: 0.1891 - val_loss: 8.1839
# Epoch 120/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6534 - loss: 1.2071
# Epoch 120: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.6534 - loss: 1.2073 - val_accuracy: 0.1857 - val_loss: 8.2154
# Epoch 121/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6539 - loss: 1.2369
# Epoch 121: val_accuracy did not improve from 0.19591
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.6539 - loss: 1.2370 - val_accuracy: 0.1925 - val_loss: 8.1613
# Epoch 122/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6331 - loss: 1.2728
# Epoch 122: val_accuracy improved from 0.19591 to 0.19761, saving model to /content/gdrive/MyDrive/Auslan App/Model/Checkpoints/camerondansbest_model.keras
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 123ms/step - accuracy: 0.6331 - loss: 1.2728 - val_accuracy: 0.1976 - val_loss: 8.2169
# Epoch 123/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6447 - loss: 1.2139
# Epoch 123: val_accuracy did not improve from 0.19761
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 122ms/step - accuracy: 0.6447 - loss: 1.2140 - val_accuracy: 0.1772 - val_loss: 8.1281
# Epoch 124/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.6591 - loss: 1.2044
# Epoch 124: val_accuracy did not improve from 0.19761
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 40s 120ms/step - accuracy: 0.6590 - loss: 1.2046 - val_accuracy: 0.1908 - val_loss: 7.9091
# Epoch 125/125
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.6583 - loss: 1.1592
# Epoch 125: val_accuracy did not improve from 0.19761
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.6583 - loss: 1.1594 - val_accuracy: 0.1959 - val_loss: 8.1551

# %%
# Evaluate on test data
final_model.evaluate(padded_test_data, test_labels)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0026 - loss: 6.5803
# [6.5761284828186035, 0.003407154930755496]

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
final_model.save('frienddidit_cam1_200_extra.keras')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Predict the test data
y_pred = model.predict(padded_test_data)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=words, yticklabels=words)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-b7ef219e9498> in <cell line: 5>()
#       3
#       4 # Predict the test data
# ----> 5 y_pred = model.predict(padded_test_data)
#       6 y_pred_classes = np.argmax(y_pred, axis=1)
#       7 y_true = np.argmax(test_labels, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in predict(self, x, batch_size, verbose, steps, callbacks)
#     506                 callbacks.on_predict_batch_begin(step)
#     507                 data = get_data(iterator)
# --> 508                 batch_outputs = self.predict_function(data)
#     509                 outputs = append_to_outputs(batch_outputs, outputs)
#     510                 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917           )
#     918       )
# --> 919       return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920           filtered_flat_args,
#     921           self._concrete_variable_creation_fn.captured_inputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
